# %%
import random

stages = ['''
  +---+
  |   |
  O   |
 /|\  |
 / \  |
      |
=========
''', '''
 +---+
  |   |
  O   |
 /|\  |
 /    |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|   |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
  |   |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
      |
      |
      |
=========
''', '''
  +---+
  |   |
      |
      |
      |
      |
=========
''']

bubble = ['jumping','athlete','boxer','wikipedia','composition','planet']
aword = random.choice(bubble)
print(aword)
# Out:
# jumping

# %%
new_word = []
for letter in aword:
    new_word.append("_") 
print(new_word)
# Out:
# ['_', '_', '_', '_', '_', '_', '_']

# %%
lives = 6
end_of_game = False
print(''' _                                             
| |                                            
| |__   __ _ _ __   __ _ _ __ ___   __ _ _ __  
| '_ \ / _` | '_ \ / _` | '_ ` _ \ / _` | '_ \ 
| | | | (_| | | | | (_| | | | | | | (_| | | | |
|_| |_|\__,_|_| |_|\__, |_| |_| |_|\__,_|_| |_|
                    __/ |                      
                   |___/                       ''')
while not end_of_game:
    guess = input("Enter the Letter: ").lower()
    for check in range(len(aword)):
        letter = aword[check]
        if letter == guess:
            new_word[check] = letter 
    if guess not in aword:
        print("You entered the mismatch letter")
        print(stages[lives])
        lives -= 1
        if lives == 0:
            end_of_game == True
            print("You Lose")
        
    print(f"{''.join(new_word)}")        
    if "_" not in new_word:
        end_of_game = True
        print("You win.")
print(lives)
# Out:
#  _
# | |
# | |__   __ _ _ __   __ _ _ __ ___   __ _ _ __
# | '_ \ / _` | '_ \ / _` | '_ ` _ \ / _` | '_ \
# | | | | (_| | | | | (_| | | | | | | (_| | | | |
# |_| |_|\__,_|_| |_|\__, |_| |_| |_|\__,_|_| |_|
#                     __/ |
#                    |___/
# Enter the Letter: k
# You entered the mismatch letter
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# ...
#
# _______
# Enter the Letter: a
# You entered the mismatch letter
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# ...
#
# _______
# Enter the Letter: r
# You entered the mismatch letter
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# ...
#
# _______
# Enter the Letter: t
# You entered the mismatch letter
#
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# ...
# _______
# Enter the Letter: h
# You entered the mismatch letter
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#       |
#       |
# ...
#
# _______
# Enter the Letter: i
# ____i__
# Enter the Letter: j
# j___i__
# Enter the Letter: k
# ...
